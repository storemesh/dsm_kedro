# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #### load kedro environment

# %%
# %load_ext kedro.extras.extensions.ipython
# Out:
# [12/02/22 11:48:40] WARNING  /home/patcharapon/miniconda3/envs/kedro-environment/lib/python3.8/site ]8;id=70854;file:///home/patcharapon/miniconda3/envs/kedro-environment/lib/python3.8/warnings.py\warnings.py]8;;\:]8;id=481703;file:///home/patcharapon/miniconda3/envs/kedro-environment/lib/python3.8/warnings.py#109\109]8;;\
#                              -packages/kedro/extras/extensions/ipython.py:18: DeprecationWarning:
#                              kedro.extras.extensions.ipython should be accessed only using the
#                              alias kedro.ipython. The unaliased name will be removed in Kedro
#                              0.19.0.
#                                warnings.warn(
# ...

# %% [markdown]
# #### Reload Kedro (if you change config)

# %%
# ! which ipython

# %%
! which jupyter
# Out:
# /home/patcharapon/miniconda3/envs/kedro-environment/bin/jupyter

# %%
# %reload_kedro
# Out:
# [12/02/22 11:38:34] INFO     No path argument was provided. Using:                                   ]8;id=412703;file:///home/patcharapon/miniconda3/envs/kedro-environment/lib/python3.8/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=840377;file:///home/patcharapon/miniconda3/envs/kedro-environment/lib/python3.8/site-packages/kedro/ipython/__init__.py#56\56]8;;\
#                              /home/patcharapon/Documents/project/kedro-project/kedro_tutorial/exampl
#                              e/rows_condition_validation/etl-pipeline
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/patcharapon/miniconda3/envs/kedro-environment/lib/python3.8/site-packages/kedro/io/core.py │
# │ :391 in parse_dataset_definition                                                                 │
# │                                                                                                  │
# ...

# %% [markdown]
# #### Get Catalog List

# %%
catalog.list()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_1377288/2446249839.py:1 in <cell line: 1>                                         │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_1377288/2446249839.py'                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'catalog' is not defined

# %% [markdown]
# #### Example of read da50_Temp_menucom_Dim_Zone_Landing_Fulltaset

# %%
respond = catalog.load('api___activity_score')
respond
# Out:
# [11/03/22 07:45:26] INFO     Loading data from 'api___activity_score' (DsmAPIDataSet)...        ]8;id=422721;file:///opt/conda/envs/kedro-environment/lib/python3.8/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=206894;file:///opt/conda/envs/kedro-environment/lib/python3.8/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# <Response [200]>

# %%
respond.json()
# Out:
# [
#     {
#         'index': 1,
#         'Activity_id': 21358,
#         'Drive_id': 11308,
#         'Activity_NameTH': 'หลักสูตรวิดีโอมาร์เก็ตติ้ง ',
#         'Activity_TypeNameTH': 'E-Learning',
#         'Activity_Start_Date': '2023-01-01T00:00:00Z',
#         'RegisterActivityURL': 'https://drive.ditp.go.th/th-TH/หน้าหลัก/รายละเอียดกิจกรรม/activityid/11308'
#     },
#     {
#         'index': 2,
#         'Activity_id': 21918,
#         'Drive_id': 11503,
#         'Activity_NameTH': 'หลักสูตร International Trader',
#         'Activity_TypeNameTH': 'E-Learning',
#         'Activity_Start_Date': '2023-01-01T00:00:00Z',
#         'RegisterActivityURL': 'https://drive.ditp.go.th/th-TH/หน้าหลัก/รายละเอียดกิจกรรม/activityid/11503'
#     },
#     {
#         'index': 3,
#         'Activity_id': 21919,
#         'Drive_id': 11503,
#         'Activity_NameTH': 'หลักสูตร International Trader',
#         'Activity_TypeNameTH': 'E-Learning',
# ...

# %%
meta

# %%
ddf.compute()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>title</th>
#       <th>unit</th>
#       <th>unit_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>system01_1</td>
#       <td>apple</td>
#       <td>ลูก</td>
#       <td>17.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>system01_2</td>
#       <td>banana</td>
#       <td>ลูก</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>system02_1</td>
#       <td>apple</td>
#       <td>ลูก</td>
#       <td>18.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>system02_2</td>
#       <td>banana</td>
# ...
