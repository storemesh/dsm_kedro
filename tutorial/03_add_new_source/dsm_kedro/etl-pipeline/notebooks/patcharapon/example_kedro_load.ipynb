# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #### load kedro environment

# %%
# %load_ext kedro.extras.extensions.ipython
# Out:
# [11/24/22 17:07:29] INFO     Updated path to Kedro project:                                          ]8;id=699704;file:///home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=274741;file:///home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/ipython/__init__.py#54\54]8;;\
#                              /home/patcharapon/Documents/project/kedro-project/kedro_tutorial/tutori
#                              al/02_dsm_kedro/dsm_kedro/etl-pipeline
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/io/core.p │
# │ y:391 in parse_dataset_definition                                                                │
# │                                                                                                  │
# │   388 │   │                                                                                      │
# │   389 │   │   trials = (_load_obj(class_path) for class_path in class_paths)                     │
# │   390 │   │   try:                                                                               │
# │ ❱ 391 │   │   │   class_obj = next(obj for obj in trials if obj is not None)                     │
# │   392 │   │   except StopIteration as exc:                                                       │
# │   393 │   │   │   raise DataSetError(                                                            │
# │   394 │   │   │   │   f"Class '{class_obj}' not found or one of its dependencies "               │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/io/core.p │
# │ y:145 in from_config                                                                             │
# │                                                                                                  │
# │   142 │   │                                                                                      │
# │   143 │   │   """                                                                                │
# │   144 │   │   try:                                                                               │
# │ ❱ 145 │   │   │   class_obj, config = parse_dataset_definition(                                  │
# │   146 │   │   │   │   config, load_version, save_version                                         │
# │   147 │   │   │   )                                                                              │
# │   148 │   │   except Exception as exc:                                                           │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/io/core.p │
# │ y:393 in parse_dataset_definition                                                                │
# │                                                                                                  │
# │   390 │   │   try:                                                                               │
# │   391 │   │   │   class_obj = next(obj for obj in trials if obj is not None)                     │
# │   392 │   │   except StopIteration as exc:                                                       │
# │ ❱ 393 │   │   │   raise DataSetError(                                                            │
# │   394 │   │   │   │   f"Class '{class_obj}' not found or one of its dependencies "               │
# │   395 │   │   │   │   f"has not been installed."                                                 │
# │   396 │   │   │   ) from exc                                                                     │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# DataSetError: Class 'dsm_kedro_plugin.custom_dataset.dsm_dataset.DsmSQLDataNode' not found or one of its
# dependencies has not been installed.
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_1386178/747376605.py:1 in <cell line: 1>                                          │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_1386178/747376605.py'                       │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/IPython/core/in │
# │ teractiveshell.py:2418 in run_line_magic                                                         │
# │                                                                                                  │
# │   2415 │   │   │   if getattr(fn, "needs_local_scope", False):                                   │
# │   2416 │   │   │   │   kwargs['local_ns'] = self.get_local_scope(stack_depth)                    │
# │   2417 │   │   │   with self.builtin_trap:                                                       │
# │ ❱ 2418 │   │   │   │   result = fn(*args, **kwargs)                                              │
# │   2419 │   │   │   return result                                                                 │
# │   2420 │                                                                                         │
# │   2421 │   def get_local_scope(self, stack_depth):                                               │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/decorator.py:23 │
# │ 2 in fun                                                                                         │
# │                                                                                                  │
# │   229 │   │   def fun(*args, **kw):                                                              │
# │   230 │   │   │   if not kwsyntax:                                                               │
# │   231 │   │   │   │   args, kw = fix(args, kw, sig)                                              │
# │ ❱ 232 │   │   │   return caller(func, *(extras + args), **kw)                                    │
# │   233 │   fun.__name__ = func.__name__                                                           │
# │   234 │   fun.__doc__ = func.__doc__                                                             │
# │   235 │   fun.__wrapped__ = func                                                                 │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/IPython/core/ma │
# │ gic.py:187 in <lambda>                                                                           │
# │                                                                                                  │
# │   184 │   # This is a closure to capture the magic_kind.  We could also use a class,             │
# │   185 │   # but it's overkill for just that one bit of state.                                    │
# │   186 │   def magic_deco(arg):                                                                   │
# │ ❱ 187 │   │   call = lambda f, *a, **k: f(*a, **k)                                               │
# │   188 │   │                                                                                      │
# │   189 │   │   if callable(arg):                                                                  │
# │   190 │   │   │   # "Naked" decorator call (just @foo, no args)                                  │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/IPython/core/ma │
# │ gics/extension.py:33 in load_ext                                                                 │
# │                                                                                                  │
# │   30 │   │   """Load an IPython extension by its module name."""                                 │
# │   31 │   │   if not module_str:                                                                  │
# │   32 │   │   │   raise UsageError('Missing module name.')                                        │
# │ ❱ 33 │   │   res = self.shell.extension_manager.load_extension(module_str)                       │
# │   34 │   │                                                                                       │
# │   35 │   │   if res == 'already loaded':                                                         │
# │   36 │   │   │   print("The %s extension is already loaded. To reload it, use:" % module_str)    │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/IPython/core/ex │
# │ tensions.py:87 in load_extension                                                                 │
# │                                                                                                  │
# │    84 │   │   │   │   │   │   │      "other Python packages, in site-packages.").format(         │
# │    85 │   │   │   │   │   │   │     dir=compress_user(self.ipython_extension_dir)))              │
# │    86 │   │   │   mod = sys.modules[module_str]                                                  │
# │ ❱  87 │   │   │   if self._call_load_ipython_extension(mod):                                     │
# │    88 │   │   │   │   self.loaded.add(module_str)                                                │
# │    89 │   │   │   else:                                                                          │
# │    90 │   │   │   │   return "no load function"                                                  │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/IPython/core/ex │
# │ tensions.py:134 in _call_load_ipython_extension                                                  │
# │                                                                                                  │
# │   131 │                                                                                          │
# │   132 │   def _call_load_ipython_extension(self, mod):                                           │
# │   133 │   │   if hasattr(mod, 'load_ipython_extension'):                                         │
# │ ❱ 134 │   │   │   mod.load_ipython_extension(self.shell)                                         │
# │   135 │   │   │   return True                                                                    │
# │   136 │                                                                                          │
# │   137 │   def _call_unload_ipython_extension(self, mod):                                         │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/ipython/_ │
# │ _init__.py:134 in load_ipython_extension                                                         │
# │                                                                                                  │
# │   131 │   │   )                                                                                  │
# │   132 │   │   return                                                                             │
# │   133 │                                                                                          │
# │ ❱ 134 │   reload_kedro(default_project_path)                                                     │
# │   135                                                                                            │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/ipython/_ │
# │ _init__.py:65 in reload_kedro                                                                    │
# │                                                                                                  │
# │    62 │   session = KedroSession.create(                                                         │
# │    63 │   │   metadata.package_name, default_project_path, env=env, extra_params=extra_params    │
# │    64 │   )                                                                                      │
# │ ❱  65 │   context = session.load_context()                                                       │
# │    66 │   catalog = context.catalog                                                              │
# │    67 │                                                                                          │
# │    68 │   get_ipython().push(                                                                    │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/framework │
# │ /session/session.py:261 in load_context                                                          │
# │                                                                                                  │
# │   258 │   │   │   extra_params=extra_params,                                                     │
# │   259 │   │   │   hook_manager=self._hook_manager,                                               │
# │   260 │   │   )                                                                                  │
# │ ❱ 261 │   │   self._hook_manager.hook.after_context_created(  # pylint: disable=no-member        │
# │   262 │   │   │   context=context                                                                │
# │   263 │   │   )                                                                                  │
# │   264                                                                                            │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/pluggy/_hooks.p │
# │ y:265 in __call__                                                                                │
# │                                                                                                  │
# │   262 │   │   else:                                                                              │
# │   263 │   │   │   firstresult = False                                                            │
# │   264 │   │                                                                                      │
# │ ❱ 265 │   │   return self._hookexec(self.name, self.get_hookimpls(), kwargs, firstresult)        │
# │   266 │                                                                                          │
# │   267 │   def call_historic(self, result_callback=None, kwargs=None):                            │
# │   268 │   │   """Call the hook with given ``kwargs`` for all registered plugins and              │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/pluggy/_manager │
# │ .py:80 in _hookexec                                                                              │
# │                                                                                                  │
# │    77 │   def _hookexec(self, hook_name, methods, kwargs, firstresult):                          │
# │    78 │   │   # called from all hookcaller instances.                                            │
# │    79 │   │   # enable_tracing will set its own wrapping function at self._inner_hookexec        │
# │ ❱  80 │   │   return self._inner_hookexec(hook_name, methods, kwargs, firstresult)               │
# │    81 │                                                                                          │
# │    82 │   def register(self, plugin, name=None):                                                 │
# │    83 │   │   """Register a plugin and return its canonical name or ``None`` if the name         │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/pluggy/_callers │
# │ .py:60 in _multicall                                                                             │
# │                                                                                                  │
# │   57 │   │   │   except StopIteration:                                                           │
# │   58 │   │   │   │   pass                                                                        │
# │   59 │   │                                                                                       │
# │ ❱ 60 │   │   return outcome.get_result()                                                         │
# │   61                                                                                             │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/pluggy/_result. │
# │ py:60 in get_result                                                                              │
# │                                                                                                  │
# │   57 │   │   │   return self._result                                                             │
# │   58 │   │   else:                                                                               │
# │   59 │   │   │   ex = self._excinfo                                                              │
# │ ❱ 60 │   │   │   raise ex[1].with_traceback(ex[2])                                               │
# │   61                                                                                             │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/pluggy/_callers │
# │ .py:39 in _multicall                                                                             │
# │                                                                                                  │
# │   36 │   │   │   │   │   except StopIteration:                                                   │
# │   37 │   │   │   │   │   │   _raise_wrapfail(gen, "did not yield")                               │
# │   38 │   │   │   │   else:                                                                       │
# │ ❱ 39 │   │   │   │   │   res = hook_impl.function(*args)                                         │
# │   40 │   │   │   │   │   if res is not None:                                                     │
# │   41 │   │   │   │   │   │   results.append(res)                                                 │
# │   42 │   │   │   │   │   │   if firstresult:  # halt further impl calls                          │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro_telemetry │
# │ /plugin.py:121 in after_context_created                                                          │
# │                                                                                                  │
# │   118 │   def after_context_created(self, context):                                              │
# │   119 │   │   """Hook implementation to send project statistics data to Heap"""                  │
# │   120 │   │                                                                                      │
# │ ❱ 121 │   │   catalog = context.catalog                                                          │
# │   122 │   │   default_pipeline = pipelines.get("__default__")  # __default__                     │
# │   123 │   │   hashed_username = _get_hashed_username()                                           │
# │   124                                                                                            │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/framework │
# │ /context/context.py:232 in catalog                                                               │
# │                                                                                                  │
# │   229 │   │   │   KedroContextError: Incorrect ``DataCatalog`` registered for the project.       │
# │   230 │   │                                                                                      │
# │   231 │   │   """                                                                                │
# │ ❱ 232 │   │   return self._get_catalog()                                                         │
# │   233 │                                                                                          │
# │   234 │   @property                                                                              │
# │   235 │   def params(self) -> Dict[str, Any]:                                                    │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/framework │
# │ /context/context.py:286 in _get_catalog                                                          │
# │                                                                                                  │
# │   283 │   │   )                                                                                  │
# │   284 │   │   conf_creds = self._get_config_credentials()                                        │
# │   285 │   │                                                                                      │
# │ ❱ 286 │   │   catalog = settings.DATA_CATALOG_CLASS.from_config(                                 │
# │   287 │   │   │   catalog=conf_catalog,                                                          │
# │   288 │   │   │   credentials=conf_creds,                                                        │
# │   289 │   │   │   load_versions=load_versions,                                                   │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/io/data_c │
# │ atalog.py:277 in from_config                                                                     │
# │                                                                                                  │
# │   274 │   │   │   │   layers[ds_layer].add(ds_name)                                              │
# │   275 │   │   │                                                                                  │
# │   276 │   │   │   ds_config = _resolve_credentials(ds_config, credentials)                       │
# │ ❱ 277 │   │   │   data_sets[ds_name] = AbstractDataSet.from_config(                              │
# │   278 │   │   │   │   ds_name, ds_config, load_versions.get(ds_name), save_version               │
# │   279 │   │   │   )                                                                              │
# │   280                                                                                            │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/io/core.p │
# │ y:149 in from_config                                                                             │
# │                                                                                                  │
# │   146 │   │   │   │   config, load_version, save_version                                         │
# │   147 │   │   │   )                                                                              │
# │   148 │   │   except Exception as exc:                                                           │
# │ ❱ 149 │   │   │   raise DataSetError(                                                            │
# │   150 │   │   │   │   f"An exception occurred when parsing config "                              │
# │   151 │   │   │   │   f"for DataSet '{name}':\n{str(exc)}"                                       │
# │   152 │   │   │   ) from exc                                                                     │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# DataSetError: An exception occurred when parsing config for DataSet 'SQLDataNode___system01___myapp_order':
# Class 'dsm_kedro_plugin.custom_dataset.dsm_dataset.DsmSQLDataNode' not found or one of its dependencies has not
# been installed.

# %% [markdown]
# #### Reload Kedro (if you change config)

# %%
# %reload_kedro
# Out:
# [11/24/22 16:46:02] INFO     No path argument was provided. Using:                                   ]8;id=114945;file:///home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=963591;file:///home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/ipython/__init__.py#56\56]8;;\
#                              /home/patcharapon/Documents/project/kedro-project/kedro_tutorial/tutori
#                              al/02_dsm_kedro/dsm_kedro/etl-pipeline
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/io/core.p │
# │ y:391 in parse_dataset_definition                                                                │
# │                                                                                                  │
# │   388 │   │                                                                                      │
# │   389 │   │   trials = (_load_obj(class_path) for class_path in class_paths)                     │
# │   390 │   │   try:                                                                               │
# │ ❱ 391 │   │   │   class_obj = next(obj for obj in trials if obj is not None)                     │
# │   392 │   │   except StopIteration as exc:                                                       │
# │   393 │   │   │   raise DataSetError(                                                            │
# │   394 │   │   │   │   f"Class '{class_obj}' not found or one of its dependencies "               │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/io/core.p │
# │ y:145 in from_config                                                                             │
# │                                                                                                  │
# │   142 │   │                                                                                      │
# │   143 │   │   """                                                                                │
# │   144 │   │   try:                                                                               │
# │ ❱ 145 │   │   │   class_obj, config = parse_dataset_definition(                                  │
# │   146 │   │   │   │   config, load_version, save_version                                         │
# │   147 │   │   │   )                                                                              │
# │   148 │   │   except Exception as exc:                                                           │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/io/core.p │
# │ y:393 in parse_dataset_definition                                                                │
# │                                                                                                  │
# │   390 │   │   try:                                                                               │
# │   391 │   │   │   class_obj = next(obj for obj in trials if obj is not None)                     │
# │   392 │   │   except StopIteration as exc:                                                       │
# │ ❱ 393 │   │   │   raise DataSetError(                                                            │
# │   394 │   │   │   │   f"Class '{class_obj}' not found or one of its dependencies "               │
# │   395 │   │   │   │   f"has not been installed."                                                 │
# │   396 │   │   │   ) from exc                                                                     │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# DataSetError: Class 'dsm_kedro_plugin.custom_dataset.dsm_dataset.DsmSQLDataNode' not found or one of its
# dependencies has not been installed.
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_1381160/2727528150.py:1 in <cell line: 1>                                         │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_1381160/2727528150.py'                      │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/IPython/core/in │
# │ teractiveshell.py:2418 in run_line_magic                                                         │
# │                                                                                                  │
# │   2415 │   │   │   if getattr(fn, "needs_local_scope", False):                                   │
# │   2416 │   │   │   │   kwargs['local_ns'] = self.get_local_scope(stack_depth)                    │
# │   2417 │   │   │   with self.builtin_trap:                                                       │
# │ ❱ 2418 │   │   │   │   result = fn(*args, **kwargs)                                              │
# │   2419 │   │   │   return result                                                                 │
# │   2420 │                                                                                         │
# │   2421 │   def get_local_scope(self, stack_depth):                                               │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/ipython/_ │
# │ _init__.py:111 in magic_reload_kedro                                                             │
# │                                                                                                  │
# │   108 │    https://kedro.readthedocs.io/en/stable/tools_integration/ipython.html for more.       │
# │   109 │   """                                                                                    │
# │   110 │   args = parse_argstring(magic_reload_kedro, line)                                       │
# │ ❱ 111 │   reload_kedro(args.path, args.env, args.params)                                         │
# │   112                                                                                            │
# │   113                                                                                            │
# │   114 def load_ipython_extension(ipython):                                                       │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/ipython/_ │
# │ _init__.py:65 in reload_kedro                                                                    │
# │                                                                                                  │
# │    62 │   session = KedroSession.create(                                                         │
# │    63 │   │   metadata.package_name, default_project_path, env=env, extra_params=extra_params    │
# │    64 │   )                                                                                      │
# │ ❱  65 │   context = session.load_context()                                                       │
# │    66 │   catalog = context.catalog                                                              │
# │    67 │                                                                                          │
# │    68 │   get_ipython().push(                                                                    │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/framework │
# │ /session/session.py:261 in load_context                                                          │
# │                                                                                                  │
# │   258 │   │   │   extra_params=extra_params,                                                     │
# │   259 │   │   │   hook_manager=self._hook_manager,                                               │
# │   260 │   │   )                                                                                  │
# │ ❱ 261 │   │   self._hook_manager.hook.after_context_created(  # pylint: disable=no-member        │
# │   262 │   │   │   context=context                                                                │
# │   263 │   │   )                                                                                  │
# │   264                                                                                            │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/pluggy/_hooks.p │
# │ y:265 in __call__                                                                                │
# │                                                                                                  │
# │   262 │   │   else:                                                                              │
# │   263 │   │   │   firstresult = False                                                            │
# │   264 │   │                                                                                      │
# │ ❱ 265 │   │   return self._hookexec(self.name, self.get_hookimpls(), kwargs, firstresult)        │
# │   266 │                                                                                          │
# │   267 │   def call_historic(self, result_callback=None, kwargs=None):                            │
# │   268 │   │   """Call the hook with given ``kwargs`` for all registered plugins and              │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/pluggy/_manager │
# │ .py:80 in _hookexec                                                                              │
# │                                                                                                  │
# │    77 │   def _hookexec(self, hook_name, methods, kwargs, firstresult):                          │
# │    78 │   │   # called from all hookcaller instances.                                            │
# │    79 │   │   # enable_tracing will set its own wrapping function at self._inner_hookexec        │
# │ ❱  80 │   │   return self._inner_hookexec(hook_name, methods, kwargs, firstresult)               │
# │    81 │                                                                                          │
# │    82 │   def register(self, plugin, name=None):                                                 │
# │    83 │   │   """Register a plugin and return its canonical name or ``None`` if the name         │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/pluggy/_callers │
# │ .py:60 in _multicall                                                                             │
# │                                                                                                  │
# │   57 │   │   │   except StopIteration:                                                           │
# │   58 │   │   │   │   pass                                                                        │
# │   59 │   │                                                                                       │
# │ ❱ 60 │   │   return outcome.get_result()                                                         │
# │   61                                                                                             │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/pluggy/_result. │
# │ py:60 in get_result                                                                              │
# │                                                                                                  │
# │   57 │   │   │   return self._result                                                             │
# │   58 │   │   else:                                                                               │
# │   59 │   │   │   ex = self._excinfo                                                              │
# │ ❱ 60 │   │   │   raise ex[1].with_traceback(ex[2])                                               │
# │   61                                                                                             │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/pluggy/_callers │
# │ .py:39 in _multicall                                                                             │
# │                                                                                                  │
# │   36 │   │   │   │   │   except StopIteration:                                                   │
# │   37 │   │   │   │   │   │   _raise_wrapfail(gen, "did not yield")                               │
# │   38 │   │   │   │   else:                                                                       │
# │ ❱ 39 │   │   │   │   │   res = hook_impl.function(*args)                                         │
# │   40 │   │   │   │   │   if res is not None:                                                     │
# │   41 │   │   │   │   │   │   results.append(res)                                                 │
# │   42 │   │   │   │   │   │   if firstresult:  # halt further impl calls                          │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro_telemetry │
# │ /plugin.py:121 in after_context_created                                                          │
# │                                                                                                  │
# │   118 │   def after_context_created(self, context):                                              │
# │   119 │   │   """Hook implementation to send project statistics data to Heap"""                  │
# │   120 │   │                                                                                      │
# │ ❱ 121 │   │   catalog = context.catalog                                                          │
# │   122 │   │   default_pipeline = pipelines.get("__default__")  # __default__                     │
# │   123 │   │   hashed_username = _get_hashed_username()                                           │
# │   124                                                                                            │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/framework │
# │ /context/context.py:232 in catalog                                                               │
# │                                                                                                  │
# │   229 │   │   │   KedroContextError: Incorrect ``DataCatalog`` registered for the project.       │
# │   230 │   │                                                                                      │
# │   231 │   │   """                                                                                │
# │ ❱ 232 │   │   return self._get_catalog()                                                         │
# │   233 │                                                                                          │
# │   234 │   @property                                                                              │
# │   235 │   def params(self) -> Dict[str, Any]:                                                    │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/framework │
# │ /context/context.py:286 in _get_catalog                                                          │
# │                                                                                                  │
# │   283 │   │   )                                                                                  │
# │   284 │   │   conf_creds = self._get_config_credentials()                                        │
# │   285 │   │                                                                                      │
# │ ❱ 286 │   │   catalog = settings.DATA_CATALOG_CLASS.from_config(                                 │
# │   287 │   │   │   catalog=conf_catalog,                                                          │
# │   288 │   │   │   credentials=conf_creds,                                                        │
# │   289 │   │   │   load_versions=load_versions,                                                   │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/io/data_c │
# │ atalog.py:277 in from_config                                                                     │
# │                                                                                                  │
# │   274 │   │   │   │   layers[ds_layer].add(ds_name)                                              │
# │   275 │   │   │                                                                                  │
# │   276 │   │   │   ds_config = _resolve_credentials(ds_config, credentials)                       │
# │ ❱ 277 │   │   │   data_sets[ds_name] = AbstractDataSet.from_config(                              │
# │   278 │   │   │   │   ds_name, ds_config, load_versions.get(ds_name), save_version               │
# │   279 │   │   │   )                                                                              │
# │   280                                                                                            │
# │                                                                                                  │
# │ /home/patcharapon/miniconda3/envs/kedro-environment3/lib/python3.8/site-packages/kedro/io/core.p │
# │ y:149 in from_config                                                                             │
# │                                                                                                  │
# │   146 │   │   │   │   config, load_version, save_version                                         │
# │   147 │   │   │   )                                                                              │
# │   148 │   │   except Exception as exc:                                                           │
# │ ❱ 149 │   │   │   raise DataSetError(                                                            │
# │   150 │   │   │   │   f"An exception occurred when parsing config "                              │
# │   151 │   │   │   │   f"for DataSet '{name}':\n{str(exc)}"                                       │
# │   152 │   │   │   ) from exc                                                                     │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# DataSetError: An exception occurred when parsing config for DataSet 'SQLDataNode___system01___myapp_order':
# Class 'dsm_kedro_plugin.custom_dataset.dsm_dataset.DsmSQLDataNode' not found or one of its dependencies has not
# been installed.

# %% [markdown]
# #### Get Catalog List

# %%
catalog.list()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_1377288/2446249839.py:1 in <cell line: 1>                                         │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_1377288/2446249839.py'                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'catalog' is not defined

# %% [markdown]
# #### Example of read da50_Temp_menucom_Dim_Zone_Landing_Fulltaset

# %%
respond = catalog.load('api___activity_score')
respond
# Out:
# [11/03/22 07:45:26] INFO     Loading data from 'api___activity_score' (DsmAPIDataSet)...        ]8;id=422721;file:///opt/conda/envs/kedro-environment/lib/python3.8/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=206894;file:///opt/conda/envs/kedro-environment/lib/python3.8/site-packages/kedro/io/data_catalog.py#343\343]8;;\
# <Response [200]>

# %%
respond.json()
# Out:
# [
#     {
#         'index': 1,
#         'Activity_id': 21358,
#         'Drive_id': 11308,
#         'Activity_NameTH': 'หลักสูตรวิดีโอมาร์เก็ตติ้ง ',
#         'Activity_TypeNameTH': 'E-Learning',
#         'Activity_Start_Date': '2023-01-01T00:00:00Z',
#         'RegisterActivityURL': 'https://drive.ditp.go.th/th-TH/หน้าหลัก/รายละเอียดกิจกรรม/activityid/11308'
#     },
#     {
#         'index': 2,
#         'Activity_id': 21918,
#         'Drive_id': 11503,
#         'Activity_NameTH': 'หลักสูตร International Trader',
#         'Activity_TypeNameTH': 'E-Learning',
#         'Activity_Start_Date': '2023-01-01T00:00:00Z',
#         'RegisterActivityURL': 'https://drive.ditp.go.th/th-TH/หน้าหลัก/รายละเอียดกิจกรรม/activityid/11503'
#     },
#     {
#         'index': 3,
#         'Activity_id': 21919,
#         'Drive_id': 11503,
#         'Activity_NameTH': 'หลักสูตร International Trader',
#         'Activity_TypeNameTH': 'E-Learning',
#         'Activity_Start_Date': '2024-01-01T00:00:00Z',
#         'RegisterActivityURL': 'https://drive.ditp.go.th/th-TH/หน้าหลัก/รายละเอียดกิจกรรม/activityid/11503'
#     },
#     {
#         'index': 4,
#         'Activity_id': 21006,
#         'Drive_id': 11000,
#         'Activity_NameTH': 'หลักสูตรภาษาอังกฤษเพื่อการค้าระหว่างประเทศ',
#         'Activity_TypeNameTH': 'E-Learning',
#         'Activity_Start_Date': '2023-01-01T00:00:00Z',
#         'RegisterActivityURL': 'https://drive.ditp.go.th/th-TH/หน้าหลัก/รายละเอียดกิจกรรม/activityid/11000'
#     },
#     {
#         'index': 5,
#         'Activity_id': 21007,
#         'Drive_id': 11000,
#         'Activity_NameTH': 'หลักสูตรภาษาอังกฤษเพื่อการค้าระหว่างประเทศ',
#         'Activity_TypeNameTH': 'E-Learning',
#         'Activity_Start_Date': '2024-01-01T00:00:00Z',
#         'RegisterActivityURL': 'https://drive.ditp.go.th/th-TH/หน้าหลัก/รายละเอียดกิจกรรม/activityid/11000'
#     },
#     {
#         'index': 6,
#         'Activity_id': 21365,
#         'Drive_id': 11309,
#         'Activity_NameTH': 'หลักสูตรการตลาดดิจิทัล ',
#         'Activity_TypeNameTH': 'E-Learning',
#         'Activity_Start_Date': '2023-01-01T00:00:00Z',
#         'RegisterActivityURL': 'https://drive.ditp.go.th/th-TH/หน้าหลัก/รายละเอียดกิจกรรม/activityid/11309'
#     },
#     {
#         'index': 7,
#         'Activity_id': 21350,
#         'Drive_id': 11306,
#         'Activity_NameTH': 'หลักสูตรการออกแบบกราฟิกเพื่อการค้ายุคใหม่ ',
#         'Activity_TypeNameTH': 'E-Learning',
#         'Activity_Start_Date': '2023-01-01T00:00:00Z',
#         'RegisterActivityURL': 'https://drive.ditp.go.th/th-TH/หน้าหลัก/รายละเอียดกิจกรรม/activityid/11306'
#     },
#     {
#         'index': 8,
#         'Activity_id': 21326,
#         'Drive_id': 11304,
#         'Activity_NameTH': 'หลักสูตรการใช้เว็บไซต์อีเบย์เพื่อการส่งออกอะไหล่ยนต์ ',
#         'Activity_TypeNameTH': 'E-Learning',
#         'Activity_Start_Date': '2023-01-01T00:00:00Z',
#         'RegisterActivityURL': 'https://drive.ditp.go.th/th-TH/หน้าหลัก/รายละเอียดกิจกรรม/activityid/11304'
#     },
#     {
#         'index': 9,
#         'Activity_id': 13072,
#         'Drive_id': 13072,
#         'Activity_NameTH': 'MEDICA 2022',
#         'Activity_TypeNameTH': 'งานแสดงสินค้าในต่างประเทศ',
#         'Activity_Start_Date': '2022-11-14T10:00:00Z',
#         'RegisterActivityURL': 'https://drive.ditp.go.th/th-TH/หน้าหลัก/รายละเอียดกิจกรรม/activityid/13072'
#     },
#     {
#         'index': 10,
#         'Activity_id': 21327,
#         'Drive_id': 11304,
#         'Activity_NameTH': 'หลักสูตรการใช้เว็บไซต์อีเบย์เพื่อการส่งออกอะไหล่ยนต์ ',
#         'Activity_TypeNameTH': 'E-Learning',
#         'Activity_Start_Date': '2024-01-01T00:00:00Z',
#         'RegisterActivityURL': 'https://drive.ditp.go.th/th-TH/หน้าหลัก/รายละเอียดกิจกรรม/activityid/11304'
#     }
# ]

# %%
meta

# %%
ddf.compute()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>title</th>
#       <th>unit</th>
#       <th>unit_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>system01_1</td>
#       <td>apple</td>
#       <td>ลูก</td>
#       <td>17.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>system01_2</td>
#       <td>banana</td>
#       <td>ลูก</td>
#       <td>9.0</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>system02_1</td>
#       <td>apple</td>
#       <td>ลูก</td>
#       <td>18.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>system02_2</td>
#       <td>banana</td>
#       <td>ลูก</td>
#       <td>10.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>
